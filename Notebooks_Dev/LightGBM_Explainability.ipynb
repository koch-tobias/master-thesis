# %%
import lightgbm as lgb 
import pickle
import matplotlib.pyplot as plt

# %%
model_path = "../models/lgbm_07062023_1559/model_9946140035906643.pkl"

# %%
with open(model_path, "rb") as fid:
    lgbm = pickle.load(fid)

# %%
import os
os.environ["PATH"] += os.pathsep + "C:/Program Files/Graphviz/bin"

# %%
ax = lgb.plot_tree(lgbm.booster_, tree_index=0, figsize=(20, 8), show_info=['split_gain'])
#ax = lgb.plot_tree(lgbm.booster_)
plt.savefig('../models/lgbm_07062023_1559/tree.png')
