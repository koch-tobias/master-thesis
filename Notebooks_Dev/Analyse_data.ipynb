# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
test_data = pd.read_excel("../models/HyperparameterTuning_27062023_2148/df_testset.xlsx")
train_data = pd.read_excel("../models/HyperparameterTuning_27062023_2148/df_trainset.xlsx")

# %%
data = pd.concat([test_data,train_data])

# %%
hist_binary = data["Relevant fuer Messung"].hist()

# %%
df_filtered = data[data['Einheitsname'] != 'Dummy']
fig = plt.figure(figsize=(30,5))
ax = fig.gca()
hist_multiclass = df_filtered["Einheitsname"].hist(ax=ax, xrot=90)

# %%
data_grouped = data.copy()
data_grouped.loc[data_grouped["Einheitsname"] != "Dummy", "Einheitsname"] = "Name"
fig = plt.figure(figsize=(30,5))
ax = fig.gca()
hist_multiclass = data_grouped["Einheitsname"].hist(ax=ax)
